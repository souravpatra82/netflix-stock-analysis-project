# %%
import pandas as pd

df = pd.read_csv("Final_nflx_data_2018-2022.csv")

df.head()
# Out:
#          date        Open        High         Low       Close   Adj Close  \
# 0  2018-01-02  196.100006  201.649994  195.419998  201.070007  201.070007
# 1  2018-01-03  202.050003  206.210007  201.500000  205.050003  205.050003
# 2  2018-01-04  206.199997  207.050003  204.000000  205.630005  205.630005
# 3  2018-01-05  207.250000  210.020004  205.589996  209.990005  209.990005
# 4  2018-01-08  210.020004  212.500000  208.440002  212.050003  212.050003
#
#      Volume    P_mean  P_sum  twt_count
# 0  10966900  0.020833     10        480
# 1   8591400  0.071217     24        337
# 2   6029600 -0.018519     -4        216
# 3   7033200 -0.019737     -6        304
# 4   5580200 -0.007663     -2        261

# %%
# !pip install matplotlib plotly

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.plot(df['date'], df['close_price'])

plt.title("Netflix Stock Price Trend")

plt.xlabel("Date")

plt.ylabel("Close Price")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(12,6))
# ...

# %%
df.columns
# Out:
# Index(['date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'P_mean',
#        'P_sum', 'twt_count'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.plot(df['date'], df['Close'])

plt.title("Netflix Stock Price Trend")

plt.xlabel("Date")

plt.ylabel("Close Price")

plt.show()

# %%
print("Highest Price:", df['high_price'].max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'high_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print("Highest Price:", df['high_price'].max())
#
# ...

# %%
high_price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 high_price
#
# NameError: name 'high_price' is not defined

# %%
print("Highest Price:", df['High'].max())
# Out:
# Highest Price: 700.98999

# %%
print("Lowest Price:", df['Low'].min())
# Out:
# Lowest Price: 162.710007

# %%
print("Average Closing Price:", df['Close'].mean())
# Out:
# Average Closing Price: 402.12801192436234

# %%
plt.figure(figsize=(12,6))

plt.bar(df['date'], df['volume'])

plt.title("Trading Volume")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'volume'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 plt.figure(figsize=(12,6))
# ----> 3 plt.bar(df['date'], df['volume'])
# ...

# %%
plt.figure(figsize=(12,6))

plt.bar(df['date'], df['Volume'])

plt.title("Trading Volume")

plt.show()

# %%
df['market_trend'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Positive vs Negative")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'market_trend'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['market_trend'].value_counts().plot.pie(autopct='%1.1f%%')
# ...

# %%
df['trend'] = df['p_sum'].apply(lambda x: 'Positive' if x > 0 else 'Negative')

df['trend'].value_counts().plot.pie(autopct='%1.1f%%')

plt.title("Positive vs Negative")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'p_sum'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['trend'] = df['p_sum'].apply(lambda x: 'Positive' if x > 0 else 'Negative')
# ...

# %%
df['trend'] = df['P_sum'].apply(lambda x: 'Positive' if x > 0 else 'Negative')

df['trend'].value_counts().plot.pie(autopct='%1.1f%%')

plt.title("Positive vs Negative")

plt.show()
